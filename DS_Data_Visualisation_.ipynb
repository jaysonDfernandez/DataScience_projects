# %% [markdown]
# <a href="https://colab.research.google.com/github/jaysonDfernandez/DataScience1/blob/main/DS_Data_Visualisation_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('/content/drive/MyDrive/Masters/Semester 1/Period 1/DataScience/1976-2016-president.csv')

# %%
data
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  Alabama       AL           1         63        41  US President
# 1     1976  Alabama       AL           1         63        41  US President
# 2     1976  Alabama       AL           1         63        41  US President
# 3     1976  Alabama       AL           1         63        41  US President
# 4     1976  Alabama       AL           1         63        41  US President
# ...    ...      ...      ...         ...        ...       ...           ...
# 3735  2016  Wyoming       WY          56         83        68  US President
# 3736  2016  Wyoming       WY          56         83        68  US President
# 3737  2016  Wyoming       WY          56         83        68  US President
# 3738  2016  Wyoming       WY          56         83        68  US President
# 3739  2016  Wyoming       WY          56         83        68  US President
#
# ...

# %%
data[data.state == 'Wisconsin']
# Out:
#       year      state state_po  state_fips  state_cen  state_ic        office  \
# 320   1976  Wisconsin       WI          55         35        25  US President
# 321   1976  Wisconsin       WI          55         35        25  US President
# 322   1976  Wisconsin       WI          55         35        25  US President
# 323   1976  Wisconsin       WI          55         35        25  US President
# 324   1976  Wisconsin       WI          55         35        25  US President
# ...    ...        ...      ...         ...        ...       ...           ...
# 3727  2016  Wisconsin       WI          55         35        25  US President
# 3728  2016  Wisconsin       WI          55         35        25  US President
# 3729  2016  Wisconsin       WI          55         35        25  US President
# 3730  2016  Wisconsin       WI          55         35        25  US President
# 3731  2016  Wisconsin       WI          55         35        25  US President
#
# ...

# %%
Wisconsin=data[data.state == 'Wisconsin']

# %%
Democrats = Wisconsin[Wisconsin.party=='democrat']

# %%
Republicans = Wisconsin[Wisconsin.party=='republican']

# %%
plt.plot(Wisconsin.year, Wisconsin.totalvotes/ 10**6)
plt.show()

# %%
plt.plot(Democrats.year, Democrats.candidatevotes/ 10**6)
plt.show()

# %%
plt.plot(Republicans.year, Republicans.candidatevotes/ 10**6)
plt.show()

# %%
plt.plot(Democrats.year, Democrats.candidatevotes/ 10**6)
plt.plot(Republicans.year, Republicans.candidatevotes/ 10**6)
plt.legend(['Democrats', 'Republicans'])
plt.xlabel('Year')
plt.ylabel('Candidate Vote')
plt.show()

# %%
plt.bar(Democrats.year, Democrats.candidatevotes/ 10**6, color ='blue',
        width = 1)
plt.bar(Republicans.year, Republicans.candidatevotes/ 10**6, color ='red',
        width = 1)
plt.legend(['Democrats', 'Republicans'])
plt.xlabel('Year')
plt.ylabel('Candidate Vote')
plt.show()

# %%
plt.bar(Democrats.year, Democrats.candidatevotes/ 10**6, color ='blue',
        width = 1)
plt.bar(Republicans.year+1, Republicans.candidatevotes/ 10**6, color ='red',
        width = 1)
plt.legend(['Democrats', 'Republicans'])
plt.xlabel('Year')
plt.ylabel('Candidate Vote')
plt.show()
